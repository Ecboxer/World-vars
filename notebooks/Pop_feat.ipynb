# %%
import pandas as pd
import numpy as np
import codecs

# %%
data = pd.read_csv('World_bank_pop.csv', encoding = 'latin-1')
data.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW    54211.0    55438.0    56225.0    56695.0
# 1  Afghanistan          AFG  8996351.0  9166764.0  9345868.0  9533954.0
# 2       Angola          AGO  5643182.0  5753024.0  5866061.0  5980417.0
# 3      Albania          ALB  1608800.0  1659800.0  1711319.0  1762621.0
# 4      Andorra          AND    13411.0    14375.0    15370.0    16412.0
#
#         1964       1965        1966        1967  ...         2008        2009  \
# 0    57032.0    57360.0     57715.0     58055.0  ...     101353.0    101453.0
# 1  9731361.0  9938414.0  10152331.0  10372630.0  ...   27294031.0  28004331.0
# 2  6093321.0  6203299.0   6309770.0   6414995.0  ...   21759420.0  22549547.0
# 3  1814135.0  1864791.0   1914573.0   1965598.0  ...    2947314.0   2927519.0
# 4    17469.0    18549.0     19647.0     20758.0  ...      83861.0     84462.0
#
# ...

# %%
# data = data.drop('2017', axis = 1)
data.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW    54211.0    55438.0    56225.0    56695.0
# 1  Afghanistan          AFG  8996351.0  9166764.0  9345868.0  9533954.0
# 2       Angola          AGO  5643182.0  5753024.0  5866061.0  5980417.0
# 3      Albania          ALB  1608800.0  1659800.0  1711319.0  1762621.0
# 4      Andorra          AND    13411.0    14375.0    15370.0    16412.0
#
#         1964       1965        1966        1967  ...         2008        2009  \
# 0    57032.0    57360.0     57715.0     58055.0  ...     101353.0    101453.0
# 1  9731361.0  9938414.0  10152331.0  10372630.0  ...   27294031.0  28004331.0
# 2  6093321.0  6203299.0   6309770.0   6414995.0  ...   21759420.0  22549547.0
# 3  1814135.0  1864791.0   1914573.0   1965598.0  ...    2947314.0   2927519.0
# 4    17469.0    18549.0     19647.0     20758.0  ...      83861.0     84462.0
#
# ...
